# %% [markdown]
# #A google colab version of the LEDITSS++ gradio demo from Brack et al., 2023.
#
# https://huggingface.co/spaces/editing-images/leditsplusplus
#
# https://doi.org/10.48550/arXiv.2311.16711

# %%
#@title 1- Clone hugging face LEDITS++ repository
# !git clone https://huggingface.co/spaces/editing-images/leditsplusplus

# %%
#@title 2- Install dependencies
# !pip install -r /content/leditsplusplus/requirements.txt
# !pip install gradio

# %%
#@title 3- Edit app.py script file to create a public link in order to access the gradio demo
file = open("/content/leditsplusplus/app.py","r")
text = file.read()
text2=text.replace("demo.launch()", "demo.launch(share=True)")
file.close()
file2 = open("/content/leditsplusplus/app.py","w")
file2.write(text2)
file2.close()

# %%
#@title 4- Start the Gradio demo, click the public link that will be created in blue at the end.
# %cd /content/leditsplusplus
# !python app.py
# Out:
# /content/leditsplusplus
# 2023-12-03 19:01:27.859680: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 19:01:27.859749: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 19:01:27.859803: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 19:01:28.924150: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# config.json: 100% 547/547 [00:00<00:00, 3.42MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 198MB/s]
# model_index.json: 100% 543/543 [00:00<00:00, 3.21MB/s]
# ...
